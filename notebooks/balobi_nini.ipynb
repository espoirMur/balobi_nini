# %%
from topic_modeling.dynamic_nmf import DynamicNMF

# %%
dynamic_nmf = DynamicNMF()

# %%
from topic_modeling.dynamic_nmf import DynamicNMF
dynamic_nmf = DynamicNMF()

# %%
dynamic_nmf.split_into_windows_docs()

# %%
for window_data in dynamic_nmf.windows_data:
# Out:
#   File "<ipython-input-3-dcc1bca08c12>", line 1
#     for window_data in dynamic_nmf.windows_data:
#                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
from topic_modeling.dynamic_nmf import DynamicNMF
dynamic_nmf = DynamicNMF()

# %%
dynamic_nmf.split_into_windows_docs()

# %%
all_coherences = []
for window_data in dynamic_nmf.windows_data:
    results = dynamic_nmf.create_topic_model(window_data)
    topics_models = results.get('topic_models')
    terms = results.get('terms')
    coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
    all_coherences.append(coherences_k)
dynamic_nmf.plot_all_coherences(all_coherences)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-eee521222b2d> in <module>
#       4     topics_models = results.get('topic_models')
#       5     terms = results.get('terms')
# ----> 6     coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
#       7     all_coherences.append(coherences_k)
#       8 dynamic_nmf.plot_all_coherences(all_coherences)
#
# NameError: name 'topic_models' is not defined

# %%
all_coherences = []
for window_data in dynamic_nmf.windows_data:
    results = dynamic_nmf.create_topic_model(window_data)
    topic_models = results.get('topic_models')
    terms = results.get('terms')
    coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
    all_coherences.append(coherences_k)
dynamic_nmf.plot_all_coherences(all_coherences)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-51bda27c115f> in <module>
#       4     topic_models = results.get('topic_models')
#       5     terms = results.get('terms')
# ----> 6     coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
#       7     all_coherences.append(coherences_k)
#       8 dynamic_nmf.plot_all_coherences(all_coherences)
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in get_best_coherence(self, topic_models, terms)
#     162         coherence_k = dict()
#     163         for (k, W, H) in topic_models:
# --> 164             coherence = self.compute_overhall_topic_coherence(H, terms)
#     165             coherence_k[k] = coherence
#     166             print("for k = {} the coherence is {:.2f}".format(k, coherence))
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in compute_overhall_topic_coherence(self, H, terms)
#     148         overhall_coherence = []
#     149         for topic_index in range(H.shape[0]):
# --> 150             topic_descriptor = self.get_descriptor(terms,
#     151                                                    H,
#     152                                                    topic_index, 10)
#
# AttributeError: 'DynamicNMF' object has no attribute 'get_descriptor'

# %%
from topic_modeling.dynamic_nmf import DynamicNMF
dynamic_nmf = DynamicNMF()

# %%
dynamic_nmf.split_into_windows_docs()

# %%
all_coherences = []
for window_data in dynamic_nmf.windows_data:
    results = dynamic_nmf.create_topic_model(window_data)
    topics_models = results.get('topic_models')
    terms = results.get('terms')
    coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
    all_coherences.append(coherences_k)
dynamic_nmf.plot_all_coherences(all_coherences)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-eee521222b2d> in <module>
#       4     topics_models = results.get('topic_models')
#       5     terms = results.get('terms')
# ----> 6     coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
#       7     all_coherences.append(coherences_k)
#       8 dynamic_nmf.plot_all_coherences(all_coherences)
#
# NameError: name 'topic_models' is not defined

# %%
all_coherences = []
for window_data in dynamic_nmf.windows_data:
    results = dynamic_nmf.create_topic_model(window_data)
    topic_models = results.get('topic_models')
    terms = results.get('terms')
    coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
    all_coherences.append(coherences_k)
dynamic_nmf.plot_all_coherences(all_coherences)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-51bda27c115f> in <module>
#       4     topic_models = results.get('topic_models')
#       5     terms = results.get('terms')
# ----> 6     coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
#       7     all_coherences.append(coherences_k)
#       8 dynamic_nmf.plot_all_coherences(all_coherences)
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in get_best_coherence(self, topic_models, terms)
#     183         coherence_k = dict()
#     184         for (k, W, H) in topic_models:
# --> 185             coherence = self.compute_overhall_topic_coherence(H, terms)
#     186             coherence_k[k] = coherence
#     187             print("for k = {} the coherence is {:.2f}".format(k, coherence))
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in compute_overhall_topic_coherence(self, H, terms)
#     171             topic_descriptor = self.get_descriptor(terms,
#     172                                                    H,
# --> 173                                                    topic_index, 10)
#     174             coherence = self.calculate_topic_coherence(topic_descriptor)
#     175             overhall_coherence.append(coherence)
#
# TypeError: get_descriptor() takes 4 positional arguments but 5 were given

# %%
from topic_modeling.dynamic_nmf import DynamicNMF
dynamic_nmf = DynamicNMF()
dynamic_nmf.split_into_windows_docs()

# %%
all_coherences = []
for window_data in dynamic_nmf.windows_data:
    results = dynamic_nmf.create_topic_model(window_data)
    topic_models = results.get('topic_models')
    terms = results.get('terms')
    coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
    all_coherences.append(coherences_k)
dynamic_nmf.plot_all_coherences(all_coherences)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-51bda27c115f> in <module>
#       4     topic_models = results.get('topic_models')
#       5     terms = results.get('terms')
# ----> 6     coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
#       7     all_coherences.append(coherences_k)
#       8 dynamic_nmf.plot_all_coherences(all_coherences)
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in get_best_coherence(self, topic_models, terms)
#     183         coherence_k = dict()
#     184         for (k, W, H) in topic_models:
# --> 185             coherence = self.compute_overhall_topic_coherence(H, terms)
#     186             coherence_k[k] = coherence
#     187             print("for k = {} the coherence is {:.2f}".format(k, coherence))
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in compute_overhall_topic_coherence(self, H, terms)
#     172                                                    H,
#     173                                                    topic_index, 10)
# --> 174             coherence = self.calculate_topic_coherence(topic_descriptor)
#     175             overhall_coherence.append(coherence)
#     176         return np.array(overhall_coherence).mean()
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in calculate_topic_coherence(self, topic_descriptor)
#     159         pairs_array = np.array(list(combinations(topics_terms, 2)))
#     160         pairs_vectors = np.apply_along_axis(self.compute_cosine_similarity, 1,
# --> 161                                             pairs_array)
#     162         return pairs_vectors.mean()
#     163
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377     except StopIteration:
#     378         raise ValueError('Cannot apply_along_axis when any iteration dimensions are 0')
# --> 379     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     380
#     381     # build a buffer for storing evaluations of func1d.
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in compute_cosine_similarity(self, words)
#     134         """
#     135         word_1, word_2 = words[0], words[1]
# --> 136         vector_1 = self.get_word_vector(word_1)
#     137         vector_2 = self.get_word_vector(word_2)
#     138         ma = np.linalg.norm(vector_1)
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in get_word_vector(self, word)
#     150         if self.check_bigram(word):
#     151             return self.get_bi_grams_vector(word)
# --> 152         return self.model_gensim.wv.get_vector(word)
#     153
#     154     def calculate_topic_coherence(self, topic_descriptor):
#
# AttributeError: 'DynamicNMF' object has no attribute 'model_gensim'

# %%
from topic_modeling.dynamic_nmf import DynamicNMF
dynamic_nmf = DynamicNMF()
dynamic_nmf.split_into_windows_docs()
dynamic_nmf.read_wv_model()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-72bb559692c3> in <module>
#       2 dynamic_nmf = DynamicNMF()
#       3 dynamic_nmf.split_into_windows_docs()
# ----> 4 dynamic_nmf.read_wv_model()
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in read_wv_model(self, model_name)
#      99             path ([type]): [description]
#     100         """
# --> 101         model_path = Path.cwd().parent.joinpath('models', model_name).__str__()
#     102         self.model_gensim = FT_gensim.load(model_path)
#     103
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/gensim/models/fasttext.py in load(cls, *args, **kwargs)
#     930         """
#     931         try:
# --> 932             model = super(FastText, cls).load(*args, **kwargs)
#     933
#     934             if not hasattr(model.trainables, 'vectors_vocab_lockf') and hasattr(model.wv, 'vectors_vocab'):
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/gensim/models/base_any2vec.py in load(cls, *args, **kwargs)
#    1228
#    1229         """
# -> 1230         model = super(BaseWordEmbeddingsModel, cls).load(*args, **kwargs)
#    1231         if not hasattr(model, 'ns_exponent'):
#    1232             model.ns_exponent = 0.75
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/gensim/models/base_any2vec.py in load(cls, fname_or_handle, **kwargs)
#     600
#     601         """
# --> 602         return super(BaseAny2VecModel, cls).load(fname_or_handle, **kwargs)
#     603
#     604     def save(self, fname_or_handle, **kwargs):
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/gensim/utils.py in load(cls, fname, mmap)
#     433         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     434
# --> 435         obj = unpickle(fname)
#     436         obj._load_specials(fname, mmap, compress, subname)
#     437         logger.info("loaded %s", fname)
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/gensim/utils.py in unpickle(fname)
#    1393
#    1394     """
# -> 1395     with open(fname, 'rb') as f:
#    1396         # Because of loading from S3 load can't be used (missing readline in smart_open)
#    1397         if sys.version_info > (3, 0):
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/smart_open/smart_open_lib.py in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, transport_params)
#     179         encoding=encoding,
#     180         errors=errors,
# --> 181         newline=newline,
#     182     )
#     183     if fobj is not None:
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/smart_open/smart_open_lib.py in _shortcut_open(uri, mode, ignore_ext, buffering, encoding, errors, newline)
#     338         open_kwargs['errors'] = errors
#     339
# --> 340     return _builtin_open(local_path, mode, buffering=buffering, **open_kwargs)
#     341
#     342
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/es.py/Projects/Personal/models/embeddings_one_gram_fast_tweets_only'

# %%
all_coherences = []
for window_data in dynamic_nmf.windows_data:
    results = dynamic_nmf.create_topic_model(window_data)
    topic_models = results.get('topic_models')
    terms = results.get('terms')
    coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
    all_coherences.append(coherences_k)
dynamic_nmf.plot_all_coherences(all_coherences)

# %%
from topic_modeling.dynamic_nmf import DynamicNMF
dynamic_nmf = DynamicNMF()
dynamic_nmf.split_into_windows_docs()

# %%
from topic_modeling.dynamic_nmf import DynamicNMF
dynamic_nmf = DynamicNMF()
dynamic_nmf.split_into_windows_docs()
dynamic_nmf.read_wv_model()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-72bb559692c3> in <module>
#       2 dynamic_nmf = DynamicNMF()
#       3 dynamic_nmf.split_into_windows_docs()
# ----> 4 dynamic_nmf.read_wv_model()
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in read_wv_model(self, model_name)
#      99             path ([type]): [description]
#     100         """
# --> 101         model_path = Path.cwd().joinpath('models', model_name).__str__()
#     102         self.model_gensim = FT_gensim.load(model_path)
#     103
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/gensim/models/fasttext.py in load(cls, *args, **kwargs)
#     930         """
#     931         try:
# --> 932             model = super(FastText, cls).load(*args, **kwargs)
#     933
#     934             if not hasattr(model.trainables, 'vectors_vocab_lockf') and hasattr(model.wv, 'vectors_vocab'):
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/gensim/models/base_any2vec.py in load(cls, *args, **kwargs)
#    1228
#    1229         """
# -> 1230         model = super(BaseWordEmbeddingsModel, cls).load(*args, **kwargs)
#    1231         if not hasattr(model, 'ns_exponent'):
#    1232             model.ns_exponent = 0.75
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/gensim/models/base_any2vec.py in load(cls, fname_or_handle, **kwargs)
#     600
#     601         """
# --> 602         return super(BaseAny2VecModel, cls).load(fname_or_handle, **kwargs)
#     603
#     604     def save(self, fname_or_handle, **kwargs):
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/gensim/utils.py in load(cls, fname, mmap)
#     433         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     434
# --> 435         obj = unpickle(fname)
#     436         obj._load_specials(fname, mmap, compress, subname)
#     437         logger.info("loaded %s", fname)
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/gensim/utils.py in unpickle(fname)
#    1393
#    1394     """
# -> 1395     with open(fname, 'rb') as f:
#    1396         # Because of loading from S3 load can't be used (missing readline in smart_open)
#    1397         if sys.version_info > (3, 0):
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/smart_open/smart_open_lib.py in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, transport_params)
#     179         encoding=encoding,
#     180         errors=errors,
# --> 181         newline=newline,
#     182     )
#     183     if fobj is not None:
#
# ~/Projects/Personal/nlp_course_coursera_russia_uni/.venv/lib/python3.6/site-packages/smart_open/smart_open_lib.py in _shortcut_open(uri, mode, ignore_ext, buffering, encoding, errors, newline)
#     338         open_kwargs['errors'] = errors
#     339
# --> 340     return _builtin_open(local_path, mode, buffering=buffering, **open_kwargs)
#     341
#     342
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/es.py/Projects/Personal/models/embeddings_one_gram_fast_tweets_only'

# %%
from topic_modeling.dynamic_nmf import DynamicNMF
dynamic_nmf = DynamicNMF()
dynamic_nmf.split_into_windows_docs()
dynamic_nmf.read_wv_model()

# %%
all_coherences = []
for window_data in dynamic_nmf.windows_data:
    results = dynamic_nmf.create_topic_model(window_data)
    topic_models = results.get('topic_models')
    terms = results.get('terms')
    coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
    all_coherences.append(coherences_k)
dynamic_nmf.plot_all_coherences(all_coherences)
# Out:
# for k = 4 the coherence is 0.42
# for k = 5 the coherence is 0.44
# for k = 6 the coherence is 0.43
# for k = 7 the coherence is 0.46
# for k = 8 the coherence is 0.45
# for k = 9 the coherence is 0.46
# for k = 10 the coherence is 0.46
# for k = 11 the coherence is 0.45
# for k = 12 the coherence is 0.46
# for k = 13 the coherence is 0.45
# for k = 14 the coherence is 0.46
# for k = 15 the coherence is 0.48
# for k = 16 the coherence is 0.47
# for k = 17 the coherence is 0.47
# for k = 18 the coherence is 0.47
# for k = 19 the coherence is 0.47
# for k = 4 the coherence is 0.49
# for k = 5 the coherence is 0.47
# for k = 6 the coherence is 0.47
# for k = 7 the coherence is 0.48
# for k = 8 the coherence is 0.48
# for k = 9 the coherence is 0.49
# for k = 10 the coherence is 0.49
# for k = 11 the coherence is 0.48
# for k = 12 the coherence is 0.48
# for k = 13 the coherence is 0.47
# for k = 14 the coherence is 0.48
# for k = 15 the coherence is 0.48
# for k = 16 the coherence is 0.47
# for k = 17 the coherence is 0.49
# for k = 18 the coherence is 0.49
# for k = 19 the coherence is 0.49
# for k = 4 the coherence is 0.51
# for k = 5 the coherence is 0.50
# for k = 6 the coherence is 0.53
# for k = 7 the coherence is 0.51
# for k = 8 the coherence is 0.51
# for k = 9 the coherence is 0.49
# for k = 10 the coherence is 0.49
# for k = 11 the coherence is 0.49
# for k = 12 the coherence is 0.50
# for k = 13 the coherence is 0.50
# for k = 14 the coherence is 0.50
# for k = 15 the coherence is 0.51
# for k = 16 the coherence is 0.50
# for k = 17 the coherence is 0.50
# for k = 18 the coherence is 0.50
# for k = 19 the coherence is 0.51
# for k = 4 the coherence is 0.41
# for k = 5 the coherence is 0.43
# for k = 6 the coherence is 0.42
# for k = 7 the coherence is 0.43
# for k = 8 the coherence is 0.44
# for k = 9 the coherence is 0.43
# for k = 10 the coherence is 0.42
# for k = 11 the coherence is 0.44
# for k = 12 the coherence is 0.42
# for k = 13 the coherence is 0.45
# for k = 14 the coherence is 0.43
# for k = 15 the coherence is 0.43
# for k = 16 the coherence is 0.41
# for k = 17 the coherence is 0.41
# for k = 18 the coherence is 0.42
# for k = 19 the coherence is 0.44
# for k = 4 the coherence is 0.51
# for k = 5 the coherence is 0.54
# for k = 6 the coherence is 0.52
# for k = 7 the coherence is 0.53
# for k = 8 the coherence is 0.51
# for k = 9 the coherence is 0.49
# for k = 10 the coherence is 0.50
# for k = 11 the coherence is 0.50
# for k = 12 the coherence is 0.49
# for k = 13 the coherence is 0.49
# for k = 14 the coherence is 0.49
# for k = 15 the coherence is 0.50
# for k = 16 the coherence is 0.50
# for k = 17 the coherence is 0.50
# for k = 18 the coherence is 0.52
# for k = 19 the coherence is 0.51
# for k = 4 the coherence is 0.53
# for k = 5 the coherence is 0.51
# for k = 6 the coherence is 0.50
# for k = 7 the coherence is 0.50
# for k = 8 the coherence is 0.50
# for k = 9 the coherence is 0.51
# for k = 10 the coherence is 0.50
# for k = 11 the coherence is 0.49
# for k = 12 the coherence is 0.50
# for k = 13 the coherence is 0.49
# for k = 14 the coherence is 0.50
# for k = 15 the coherence is 0.49
# for k = 16 the coherence is 0.50
# for k = 17 the coherence is 0.48
# for k = 18 the coherence is 0.48
# for k = 19 the coherence is 0.50
# for k = 4 the coherence is 0.54
# for k = 5 the coherence is 0.53
# for k = 6 the coherence is 0.54
# for k = 7 the coherence is 0.55
# for k = 8 the coherence is 0.55
# for k = 9 the coherence is 0.53
# for k = 10 the coherence is 0.54
# for k = 11 the coherence is 0.53
# for k = 12 the coherence is 0.54
# for k = 13 the coherence is 0.54
# for k = 14 the coherence is 0.52
# for k = 15 the coherence is 0.52
# for k = 16 the coherence is 0.51
# for k = 17 the coherence is 0.51
# for k = 18 the coherence is 0.51
# for k = 19 the coherence is 0.50
# for k = 4 the coherence is 0.53
# for k = 5 the coherence is 0.51
# for k = 6 the coherence is 0.50
# for k = 7 the coherence is 0.53
# for k = 8 the coherence is 0.53
# for k = 9 the coherence is 0.53
# for k = 10 the coherence is 0.52
# for k = 11 the coherence is 0.51
# for k = 12 the coherence is 0.51
# for k = 13 the coherence is 0.51
# for k = 14 the coherence is 0.51
# for k = 15 the coherence is 0.51
# for k = 16 the coherence is 0.51
# for k = 17 the coherence is 0.50
# for k = 18 the coherence is 0.49
# for k = 19 the coherence is 0.49
# for k = 4 the coherence is 0.52
# for k = 5 the coherence is 0.49
# for k = 6 the coherence is 0.50
# for k = 7 the coherence is 0.50
# for k = 8 the coherence is 0.52
# for k = 9 the coherence is 0.52
# for k = 10 the coherence is 0.51
# for k = 11 the coherence is 0.52
# for k = 12 the coherence is 0.51
# for k = 13 the coherence is 0.50
# for k = 14 the coherence is 0.50
# for k = 15 the coherence is 0.49
# for k = 16 the coherence is 0.50
# for k = 17 the coherence is 0.51
# for k = 18 the coherence is 0.50
# for k = 19 the coherence is 0.50
# for k = 4 the coherence is 0.51
# for k = 5 the coherence is 0.50
# for k = 6 the coherence is 0.51
# for k = 7 the coherence is 0.52
# for k = 8 the coherence is 0.52
# for k = 9 the coherence is 0.53
# for k = 10 the coherence is 0.52
# for k = 11 the coherence is 0.53
# for k = 12 the coherence is 0.53
# for k = 13 the coherence is 0.52
# for k = 14 the coherence is 0.52
# for k = 15 the coherence is 0.51
# for k = 16 the coherence is 0.52
# for k = 17 the coherence is 0.52
# for k = 18 the coherence is 0.52
# for k = 19 the coherence is 0.53
# for k = 4 the coherence is 0.46
# for k = 5 the coherence is 0.45
# for k = 6 the coherence is 0.46
# for k = 7 the coherence is 0.46
# for k = 8 the coherence is 0.46
# for k = 9 the coherence is 0.46
# for k = 10 the coherence is 0.48
# for k = 11 the coherence is 0.49
# for k = 12 the coherence is 0.48
# for k = 13 the coherence is 0.47
# for k = 14 the coherence is 0.47
# for k = 15 the coherence is 0.47
# for k = 16 the coherence is 0.49
# for k = 17 the coherence is 0.49
# for k = 18 the coherence is 0.49
# for k = 19 the coherence is 0.49
# for k = 4 the coherence is 0.48
# for k = 5 the coherence is 0.46
# for k = 6 the coherence is 0.49
# for k = 7 the coherence is 0.48
# for k = 8 the coherence is 0.50
# for k = 9 the coherence is 0.53
# for k = 10 the coherence is 0.52
# for k = 11 the coherence is 0.51
# for k = 12 the coherence is 0.52
# for k = 13 the coherence is 0.51
# for k = 14 the coherence is 0.51
# for k = 15 the coherence is 0.53
# for k = 16 the coherence is 0.52
# for k = 17 the coherence is 0.52
# for k = 18 the coherence is 0.51
# for k = 19 the coherence is 0.52
# for k = 4 the coherence is 0.53
# for k = 5 the coherence is 0.51
# for k = 6 the coherence is 0.52
# for k = 7 the coherence is 0.54
# for k = 8 the coherence is 0.53
# for k = 9 the coherence is 0.54
# for k = 10 the coherence is 0.53
# for k = 11 the coherence is 0.53
# for k = 12 the coherence is 0.54
# for k = 13 the coherence is 0.55
# for k = 14 the coherence is 0.54
# for k = 15 the coherence is 0.55
# for k = 16 the coherence is 0.54
# for k = 17 the coherence is 0.54
# for k = 18 the coherence is 0.54
# for k = 19 the coherence is 0.55
# for k = 4 the coherence is 0.53
# for k = 5 the coherence is 0.49
# for k = 6 the coherence is 0.52
# for k = 7 the coherence is 0.55
# for k = 8 the coherence is 0.52
# for k = 9 the coherence is 0.53
# for k = 10 the coherence is 0.51
# for k = 11 the coherence is 0.52
# for k = 12 the coherence is 0.52
# for k = 13 the coherence is 0.51
# for k = 14 the coherence is 0.51
# for k = 15 the coherence is 0.52
# for k = 16 the coherence is 0.52
# for k = 17 the coherence is 0.52
# for k = 18 the coherence is 0.51
# for k = 19 the coherence is 0.51
# for k = 4 the coherence is 0.53
# for k = 5 the coherence is 0.49
# for k = 6 the coherence is 0.51
# for k = 7 the coherence is 0.53
# for k = 8 the coherence is 0.52
# for k = 9 the coherence is 0.52
# for k = 10 the coherence is 0.51
# for k = 11 the coherence is 0.52
# for k = 12 the coherence is 0.50
# for k = 13 the coherence is 0.50
# for k = 14 the coherence is 0.49
# for k = 15 the coherence is 0.50
# for k = 16 the coherence is 0.51
# for k = 17 the coherence is 0.50
# for k = 18 the coherence is 0.51
# for k = 19 the coherence is 0.51
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-51bda27c115f> in <module>
#       6     coherences_k = dynamic_nmf.get_best_coherence(topic_models, terms)
#       7     all_coherences.append(coherences_k)
# ----> 8 dynamic_nmf.plot_all_coherences(all_coherences)
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in plot_all_coherences(self, all_coherences_k)
#     216         axes = axes.flatten()
#     217         for coherences_k, axe in zip(all_coherences_k, axes):
# --> 218             self.plot_topic_coherence(coherences_k, axe)
#
# ~/Projects/Personal/balobi_nini/topic_modeling/dynamic_nmf.py in plot_topic_coherence(self, coherences_k, axe)
#     194         """
#     195         axe.plot(coherences_k.keys(), coherences_k.values() )
# --> 196         axe.xticks(list(coherences_k.keys()))
#     197         axe.xlabel("Number of Topics")
#     198         axe.ylabel("Mean Coherence")
#
# AttributeError: 'AxesSubplot' object has no attribute 'xticks'

# %%
import json
from pathlib import Path

result_path = Path.cwd().joinpath('data', 'topic_nmf_results.json')
with open(result_path, 'w') as fout:
    json.dump(all_coherences, fout)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-7a39c12f2256> in <module>
#       4 result_path = Path.cwd().joinpath('data', 'topic_nmf_results.json')
#       5 with open(result_path, 'w') as fout:
# ----> 6     json.dump(all_coherences, fout)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     426             yield _floatstr(o)
#     427         elif isinstance(o, (list, tuple)):
# --> 428             yield from _iterencode_list(o, _current_indent_level)
#     429         elif isinstance(o, dict):
#     430             yield from _iterencode_dict(o, _current_indent_level)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     402                 else:
#     403                     chunks = _iterencode(value, _current_indent_level)
# --> 404                 yield from chunks
#     405         if newline_indent is not None:
#     406             _current_indent_level -= 1
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     435                     raise ValueError("Circular reference detected")
#     436                 markers[markerid] = o
# --> 437             o = _default(o)
#     438             yield from _iterencode(o, _current_indent_level)
#     439             if markers is not None:
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/json/encoder.py in default(self, o)
#     178         """
#     179         raise TypeError("Object of type '%s' is not JSON serializable" %
# --> 180                         o.__class__.__name__)
#     181
#     182     def encode(self, o):
#
# TypeError: Object of type 'float32' is not JSON serializable

# %%
all_coherences[0]
# Out:
# {4: 0.42496496,
#  5: 0.44391656,
#  6: 0.4307308,
#  7: 0.46280593,
#  8: 0.4546935,
#  9: 0.45961365,
#  10: 0.456309,
#  11: 0.44503412,
#  12: 0.45837095,
#  13: 0.45260653,
#  14: 0.45850915,
#  15: 0.4770818,
#  16: 0.46875665,
#  17: 0.46604958,
#  18: 0.4698113,
#  19: 0.47275367}

# %%
all_coherences[-1]
# Out:
# {4: 0.5254885,
#  5: 0.485317,
#  6: 0.5121955,
#  7: 0.52802074,
#  8: 0.5189973,
#  9: 0.5189971,
#  10: 0.5072583,
#  11: 0.51562494,
#  12: 0.49745655,
#  13: 0.49782306,
#  14: 0.49204633,
#  15: 0.50489837,
#  16: 0.5122241,
#  17: 0.50467896,
#  18: 0.5085574,
#  19: 0.50588626}

# %%
all_coherences[-1].get(4)
# Out:
# 0.5254885

# %%
type(all_coherences[-1].get(4))
# Out:
# numpy.float32

# %%
for index, coherences_k in enumerate(all_coherences):
    all_coherences[index] = {k: float(v) for k, v in coherences_k.items()}

# %%
type(all_coherences[-1].get(4))
# Out:
# float

# %%
import json
from pathlib import Path

result_path = Path.cwd().joinpath('data', 'topic_nmf_results.json')
with open(result_path, 'w') as fout:
    json.dump(all_coherences, fout)

# %%
def plot_topic_coherence(coherences_k, axe):
    """
    plot the coherence for each k in the topic model
    """
    axe.plot(coherences_k.keys(), coherences_k.values())
    axe.set_xtick(list(coherences_k.keys()))
    axe.set_xlabel("Number of Topics")
    axe.set_ylabel("Mean Coherence")
    # add the points
    axe.scatter(coherences_k.keys(), coherences_k.values(), s=120)
    # find and annotate the maximum point on the plot
    ymax = max(coherences_k.values())
    best_k = max(coherences_k, key=coherences_k.get)
    axe.annotate("k={}".format(best_k),
                  xy=(best_k, ymax),
                  xytext=(best_k, ymax),
                  textcoords="offset points", fontsize=16)

# %%
def plot_all_coherences(self, all_coherences_k):
    """
    plot for all windows topic model the evolution of coherence measure
    """
    fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(8, 4))
    axes = axes.flatten()
    for coherences_k, axe in zip(all_coherences_k, axes):
        plot_topic_coherence(coherences_k, axe)

# %%
plot_all_coherences(all_coherences)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-c7999177a38d> in <module>
# ----> 1 plot_all_coherences(all_coherences)
#
# TypeError: plot_all_coherences() missing 1 required positional argument: 'all_coherences_k'

# %%
def plot_all_coherences(all_coherences_k):
    """
    plot for all windows topic model the evolution of coherence measure
    """
    fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(8, 4))
    axes = axes.flatten()
    for coherences_k, axe in zip(all_coherences_k, axes):
        plot_topic_coherence(coherences_k, axe)

# %%
plot_all_coherences(all_coherences)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c7999177a38d> in <module>
# ----> 1 plot_all_coherences(all_coherences)
#
# <ipython-input-14-1a3c3448dd41> in plot_all_coherences(all_coherences_k)
#       3     plot for all windows topic model the evolution of coherence measure
#       4     """
# ----> 5     fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(8, 4))
#       6     axes = axes.flatten()
#       7     for coherences_k, axe in zip(all_coherences_k, axes):
#
# NameError: name 'plt' is not defined

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.style.use("ggplot")
matplotlib.rcParams.update({"font.size": 14})
# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.style.use("ggplot")
matplotlib.rcParams.update({"font.size": 14})

# %%
plot_all_coherences(all_coherences)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-c7999177a38d> in <module>
# ----> 1 plot_all_coherences(all_coherences)
#
# <ipython-input-14-1a3c3448dd41> in plot_all_coherences(all_coherences_k)
#       6     axes = axes.flatten()
#       7     for coherences_k, axe in zip(all_coherences_k, axes):
# ----> 8         plot_topic_coherence(coherences_k, axe)
#
# <ipython-input-11-29fee11f40c8> in plot_topic_coherence(coherences_k, axe)
#       4     """
#       5     axe.plot(coherences_k.keys(), coherences_k.values())
# ----> 6     axe.set_xtick(list(coherences_k.keys()))
#       7     axe.set_xlabel("Number of Topics")
#       8     axe.set_ylabel("Mean Coherence")
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_xtick'

# %%
def plot_topic_coherence(coherences_k, axe):
    """
    plot the coherence for each k in the topic model
    """
    axe.plot(coherences_k.keys(), coherences_k.values())
    axe.set_xticks(list(coherences_k.keys()))
    axe.set_xlabel("Number of Topics")
    axe.set_ylabel("Mean Coherence")
    # add the points
    axe.scatter(coherences_k.keys(), coherences_k.values(), s=120)
    # find and annotate the maximum point on the plot
    ymax = max(coherences_k.values())
    best_k = max(coherences_k, key=coherences_k.get)
    axe.annotate("k={}".format(best_k),
                  xy=(best_k, ymax),
                  xytext=(best_k, ymax),
                  textcoords="offset points", fontsize=16)

# %%
plot_all_coherences(all_coherences)

# %%
def plot_all_coherences(all_coherences_k):
    """
    plot for all windows topic model the evolution of coherence measure
    """
    fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(20, 10))
    axes = axes.flatten()
    for coherences_k, axe in zip(all_coherences_k, axes):
        plot_topic_coherence(coherences_k, axe)

# %%
plot_all_coherences(all_coherences)

# %%
def plot_all_coherences(all_coherences_k):
    """
    plot for all windows topic model the evolution of coherence measure
    """
    fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(40, 20))
    axes = axes.flatten()
    for coherences_k, axe in zip(all_coherences_k, axes):
        plot_topic_coherence(coherences_k, axe)

# %%
plot_all_coherences(all_coherences)

# %%
#As of now we have an array of all the topic models and on another end we have for each model the best k , we need do combine them and get for each timedelta the topic model with the corresponding best k

# %%
def get_best_k(coherences_k):
    best_k = max(coherences_k, key=coherences_k.get)
    return best_k

# %%
map(all_coherences, get_best_k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-ce2005b20199> in <module>
# ----> 1 map(all_coherences, get_best_k)
#
# TypeError: 'function' object is not iterable

# %%
map(get_best_k, all_coherences)

# %%
list(map(get_best_k, all_coherences))
# Out:
# [15, 19, 6, 13, 5, 4, 7, 4, 8, 9, 16, 9, 19, 7, 7]

# %%
best_coherences = list(map(get_best_k, all_coherences))
